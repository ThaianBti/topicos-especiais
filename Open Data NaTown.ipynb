# %%
### Libraries necessary to run this IPython Notebook

# !pip install folium
# !pip install geocoder
# !pip install tqdm

# %%
# Load relevant libraries
import pandas as pd
import numpy as np
import matplotlib
import folium
import geocoder
from tqdm import tqdm
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### 1.1 Load the data

# %%
# Load schools information data and display the header
df = pd.read_csv('municipal_schools.csv', sep=';')
df.head(10)
# Out:
#    Ordem                           Estabelecimento Forma Ocupação Prédio  \
# 0      1                     ESC MUL 4º CENTENÁRIO                CEDIDO
# 1      1                     ESC MUL 4º CENTENÁRIO                     -
# 2      2                ESC MUL CELESTINO PIMENTEL               PRÓPRIO
# 3      3                    ESC MUL CHICO SANTEIRO               PRÓPRIO
# 4      4                   ESC MUL DJALMA MARANHÃO               PRÓPRIO
# 5      5        ESC MUL ESTUDANTE EMMANUEL BEZERRA               PRÓPRIO
# 6      6   ESC MUL FERREIRA ITAJUBÁ ENS DE 1º GRAU               PRÓPRIO
# 7      7              ESC MUL HENRIQUE CASTRICIANO               PRÓPRIO
# 8      7              ESC MUL HENRIQUE CASTRICIANO                     -
# 9      8  ESC MUL IRMÃ ARCÂNGELA ENSINO DE 1º GRAU               PRÓPRIO
#
#   Local Funcionamento
# 0      PRÉDIO ESCOLAR
# 1         OUTRO LUGAR
# 2      PRÉDIO ESCOLAR
# 3      PRÉDIO ESCOLAR
# 4      PRÉDIO ESCOLAR
# 5      PRÉDIO ESCOLAR
# ...

# %%
# Load health units information data and display the header
df = pd.read_csv('health_units.csv', sep=';')
df.head(10)
# Out:
#   Distrito Sanitário      Unidade  \
# 0              Leste  UBS ALECRIM
# 1              Leste  UBS ALECRIM
# 2              Leste  UBS ALECRIM
# 3              Leste  UBS ALECRIM
# 4              Leste  UBS ALECRIM
# 5              Leste  UBS ALECRIM
# 6              Leste  UBS ALECRIM
# 7              Leste  UBS ALECRIM
# 8              Leste  UBS ALECRIM
# 9              Leste  UBS ALECRIM
#
#                                  Serviços Oferecidos          Tipo de Unidade
# 0                                         Imunização  Unidade Básica de Saúde
# 1                                   Teste do Pezinho  Unidade Básica de Saúde
# 2  Exame Citopatológico do Colo de Útero (Prevent...  Unidade Básica de Saúde
# 3                                                PPD  Unidade Básica de Saúde
# 4                                                BCG  Unidade Básica de Saúde
# 5                            Aplicação de Vitamina A  Unidade Básica de Saúde
# ...

# %%
# Load health employees information data and display the header
df = pd.read_csv('health_employees.csv', sep=';')
df.head(10)
# Out:
#        UNIDADE                 NOME DO PROFISSIONAL  \
# 0  PONTA NEGRA             NEUMA LÚCIA DE OLIVEIRA
# 1  PONTA NEGRA               MUCIA TEIXEIRA BATISTA
# 2  PONTA NEGRA   MEINE SIOMARA ALCANTARA DE ALMEIDA
# 3  PONTA NEGRA       GERUSA DE SOUZA MARQUES MACEDO
# 4  PONTA NEGRA             MIRIAM DANTAS DE MACEDO
# 5  PONTA NEGRA                 BIANCA DE MELO SOUZA
# 6  PONTA NEGRA             CINTIA FERNANDES DE LIMA
# 7  PONTA NEGRA           DULCILEIDE SOUZA DE ARAUJO
# 8  PONTA NEGRA         VERA LUCIA DE MOURA SANTIAGO
# 9  PONTA NEGRA         ELIZABETH OLIVEIRA DE MACEDO
#
#                  ESPECIALIDADE                          HORÁRIO
# 0           CIRURGIÃO DENTISTA  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 1                   ENFERMEIRO  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 2                   ENFERMEIRO  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 3                       MÉDICO  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 4                       MÉDICO  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# ...
